# %% [markdown]
# ### Libraries

# %%
import pandas as pd
import numpy as np
from datetime import datetime as dt
import warnings
import itertools
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import matplotlib
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.seasonal import seasonal_decompose

warnings.filterwarnings("ignore")

# %% [markdown]
# ### Functions

# %%
def mape(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %% [markdown]
# ### Data Preprocessing

# %%
data = pd.read_csv('./Data/resultAnalysis.csv', sep = ';', encoding = 'cp1254')
data.head()
# Out:
#               Datetime  PJM_Load_MW    Weekday        Date    Year  Month  \
# 0  1998-04-01 00:00:00            2        NaN         NaN     NaN    NaN
# 1  1998-04-01 01:00:00            2  Wednesday  1998-04-01  1998.0    4.0
# 2  1998-04-01 02:00:00            2  Wednesday  1998-04-01  1998.0    4.0
# 3  1998-04-01 03:00:00            2  Wednesday  1998-04-01  1998.0    4.0
# 4  1998-04-01 04:00:00            2  Wednesday  1998-04-01  1998.0    4.0
#
#    Season  Day      Time  Hour  Minute  Week  DayOfWeek LeapYear
# 0     NaN  NaN       NaN   NaN     NaN   NaN        NaN      NaN
# 1  Spring  1.0  01:00:00   1.0     0.0  14.0        2.0    False
# 2  Spring  1.0  02:00:00   2.0     0.0  14.0        2.0    False
# 3  Spring  1.0  03:00:00   3.0     0.0  14.0        2.0    False
# 4  Spring  1.0  04:00:00   4.0     0.0  14.0        2.0    False

# %%
data.dtypes
# Out:
# Datetime        object
# PJM_Load_MW      int64
# Weekday         object
# Date            object
# Year           float64
# Month          float64
# Season          object
# Day            float64
# Time            object
# Hour           float64
# Minute         float64
# Week           float64
# DayOfWeek      float64
# LeapYear        object
# dtype: object

# %%
data.Datetime = pd.to_datetime(data.Datetime)
data = data.sort_values(by = ['Datetime']).reset_index(drop= True)
data.dtypes
# Out:
# Datetime       datetime64[ns]
# PJM_Load_MW             int64
# Weekday                object
# Date                   object
# Year                  float64
# Month                 float64
# Season                 object
# Day                   float64
# Time                   object
# Hour                  float64
# Minute                float64
# Week                  float64
# DayOfWeek             float64
# LeapYear               object
# dtype: object

# %%
# Converting to Datetime format
df_data = data[['Datetime','PJM_Load_MW']].set_index('Datetime')
df_data
# Out:
#                      PJM_Load_MW
# Datetime
# 1998-04-01 00:00:00            2
# 1998-04-01 01:00:00            2
# 1998-04-01 02:00:00            2
# 1998-04-01 03:00:00            2
# 1998-04-01 04:00:00            2
# ...                          ...
# 2001-12-31 19:00:00            4
# 2001-12-31 20:00:00            4
# 2001-12-31 21:00:00            4
# 2001-12-31 22:00:00            3
# 2001-12-31 23:00:00            3
#
# [32904 rows x 1 columns]

# %%
# Converting the data to monthly based
df_data = pd.DataFrame(columns = ['Date', 'Month', 'PJM_Load_MW'])
df_data['Year'] = data['Datetime'].dt.year
df_data['Month'] = data['Datetime'].dt.month
df_data['PJM_Load_MW'] = data['PJM_Load_MW'].copy()
df_data = df_data.groupby(['Year','Month'])['PJM_Load_MW'].sum().reset_index()
df_data['Date'] = df_data.apply(lambda x: str(x['Year']) + '-' + str(x['Month']), axis = 1)
df_data['Date'] = pd.to_datetime(df_data['Date'])
df_data = df_data.set_index('Date')
df_data.drop(['Year','Month'], axis = 1, inplace = True)
df_data
# Out:
#             PJM_Load_MW
# Date
# 1998-04-01         1842
# 1998-05-01         1975
# 1998-06-01         2138
# 1998-07-01         2426
# 1998-08-01         2469
# 1998-09-01         2122
# 1998-10-01         1916
# 1998-11-01         1880
# 1998-12-01         2105
# 1999-01-01         2273
# 1999-02-01         1966
# 1999-03-01         2116
# 1999-04-01         1852
# 1999-05-01         1917
# 1999-06-01         2258
# 1999-07-01         2735
# 1999-08-01         2507
# 1999-09-01         2063
# 1999-10-01         1967
# 1999-11-01         1916
# 1999-12-01         2205
# 2000-01-01         2395
# 2000-02-01         2148
# 2000-03-01         2035
# 2000-04-01         1878
# 2000-05-01         2036
# 2000-06-01         2338
# 2000-07-01         2342
# 2000-08-01         2426
# 2000-09-01         2116
# 2000-10-01         1975
# 2000-11-01         2034
# 2000-12-01         2481
# 2001-01-01         2467
# 2001-02-01         2054
# 2001-03-01         2183
# 2001-04-01         1911
# 2001-05-01         2022
# 2001-06-01         2353
# 2001-07-01         2410
# 2001-08-01         2724
# 2001-09-01         2069
# 2001-10-01         1984
# 2001-11-01         1918
# 2001-12-01         2153

# %%
df_data_x = df_data['1998-04-01':'2001-03-01']
len(df_data_x)
# Out:
# 36

# %%
df_data_y = df_data['2001-04-01':]
len(df_data_y)
# Out:
# 9

# %% [markdown]
# ### Forecasting

# %%
result_a = seasonal_decompose(df_data_x['PJM_Load_MW'], model = 'multiplicative')
result_a.plot()

# %%
# Hyperparameter tuning for p, d, q, P, D, Q values
p = d = q = range(0, 3)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = SARIMAX(df_data_x,order=param,seasonal_order=param_seasonal,enforce_stationarity=False,enforce_invertibility=False)
            results = mod.fit()
            print('ARIMA{}x{}12 - MSE:{}'.format(param,param_seasonal,results.mse))
        except: 
            continue
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - MSE:4690623.777777778
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - MSE:2622843.9567746953
# ARIMA(0, 0, 0)x(0, 0, 2, 12)12 - MSE:2446812.8674963242
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - MSE:1499790.4444444445
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - MSE:1498878.154917811
# ARIMA(0, 0, 0)x(0, 1, 2, 12)12 - MSE:1499790.4444444445
# ARIMA(0, 0, 0)x(0, 2, 0, 12)12 - MSE:1874095.5710575883
# ARIMA(0, 0, 0)x(0, 2, 1, 12)12 - MSE:2118534.117437229
# ARIMA(0, 0, 0)x(0, 2, 2, 12)12 - MSE:2117792.820018298
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - MSE:1498652.443524692
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - MSE:1496006.8666489634
# ARIMA(0, 0, 0)x(1, 0, 2, 12)12 - MSE:1500705.5749496736
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - MSE:1664967.3566204775
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - MSE:1708441.580771929
# ARIMA(0, 0, 0)x(1, 1, 2, 12)12 - MSE:1499790.4444444445
# ARIMA(0, 0, 0)x(1, 2, 0, 12)12 - MSE:2119397.1930826064
# ARIMA(0, 0, 0)x(1, 2, 1, 12)12 - MSE:2118534.117437229
# ARIMA(0, 0, 0)x(1, 2, 2, 12)12 - MSE:2117792.820018298
# ARIMA(0, 0, 0)x(2, 0, 0, 12)12 - MSE:3031305.6837904123
# ARIMA(0, 0, 0)x(2, 0, 1, 12)12 - MSE:3032269.73929287
# ARIMA(0, 0, 0)x(2, 0, 2, 12)12 - MSE:3093021.2337612193
# ARIMA(0, 0, 0)x(2, 1, 0, 12)12 - MSE:1499790.4444444445
# ARIMA(0, 0, 0)x(2, 1, 1, 12)12 - MSE:1499790.4444444445
# ARIMA(0, 0, 0)x(2, 1, 2, 12)12 - MSE:1499790.4444444445
# ARIMA(0, 0, 0)x(2, 2, 0, 12)12 - MSE:2119397.1930826064
# ARIMA(0, 0, 0)x(2, 2, 1, 12)12 - MSE:2118534.117437229
# ARIMA(0, 0, 0)x(2, 2, 2, 12)12 - MSE:2117792.820018298
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - MSE:1470270.7262679387
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - MSE:1470673.3177450576
# ARIMA(0, 0, 1)x(0, 0, 2, 12)12 - MSE:2191395.927186893
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - MSE:1479362.0952279766
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - MSE:1490712.0218317057
# ARIMA(0, 0, 1)x(0, 1, 2, 12)12 - MSE:1491716.78403413
# ARIMA(0, 0, 1)x(0, 2, 0, 12)12 - MSE:1846244.691366224
# ARIMA(0, 0, 1)x(0, 2, 1, 12)12 - MSE:2103965.7173117525
# ARIMA(0, 0, 1)x(0, 2, 2, 12)12 - MSE:2107722.639869216
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - MSE:1483182.3142514478
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - MSE:1502615.0861744056
# ARIMA(0, 0, 1)x(1, 0, 2, 12)12 - MSE:1495984.2685568312
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - MSE:1779011.3610944394
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - MSE:1814861.9064212514
# ARIMA(0, 0, 1)x(1, 1, 2, 12)12 - MSE:1491716.78403413
# ARIMA(0, 0, 1)x(1, 2, 0, 12)12 - MSE:2103105.4078467945
# ARIMA(0, 0, 1)x(1, 2, 1, 12)12 - MSE:2103965.7173117525
# ARIMA(0, 0, 1)x(1, 2, 2, 12)12 - MSE:2107722.639869216
# ARIMA(0, 0, 1)x(2, 0, 0, 12)12 - MSE:3157602.8431632426
# ARIMA(0, 0, 1)x(2, 0, 1, 12)12 - MSE:2019601.1246487142
# ARIMA(0, 0, 1)x(2, 0, 2, 12)12 - MSE:86914904.8387971
# ARIMA(0, 0, 1)x(2, 1, 0, 12)12 - MSE:1491292.5306970456
# ARIMA(0, 0, 1)x(2, 1, 1, 12)12 - MSE:1491292.5306970456
# ARIMA(0, 0, 1)x(2, 1, 2, 12)12 - MSE:1491716.78403413
# ARIMA(0, 0, 1)x(2, 2, 0, 12)12 - MSE:2107575.1092198193
# ARIMA(0, 0, 1)x(2, 2, 1, 12)12 - MSE:2107575.1092198193
# ARIMA(0, 0, 1)x(2, 2, 2, 12)12 - MSE:2107722.639869216
# ARIMA(0, 0, 2)x(0, 0, 0, 12)12 - MSE:742653.3264352587
# ARIMA(0, 0, 2)x(0, 0, 1, 12)12 - MSE:1119898.466873893
# ARIMA(0, 0, 2)x(0, 0, 2, 12)12 - MSE:2112560.2356443857
# ARIMA(0, 0, 2)x(0, 1, 0, 12)12 - MSE:1490966.655625083
# ARIMA(0, 0, 2)x(0, 1, 1, 12)12 - MSE:1490359.2475354515
# ARIMA(0, 0, 2)x(0, 1, 2, 12)12 - MSE:1495107.824028255
# ARIMA(0, 0, 2)x(0, 2, 0, 12)12 - MSE:1949534.6254135056
# ARIMA(0, 0, 2)x(0, 2, 1, 12)12 - MSE:2154007.2526678196
# ARIMA(0, 0, 2)x(0, 2, 2, 12)12 - MSE:2141278.498044354
# ARIMA(0, 0, 2)x(1, 0, 0, 12)12 - MSE:1503130.910565279
# ARIMA(0, 0, 2)x(1, 0, 1, 12)12 - MSE:1454119.418348317
# ARIMA(0, 0, 2)x(1, 0, 2, 12)12 - MSE:1482834.8441717578
# ARIMA(0, 0, 2)x(1, 1, 0, 12)12 - MSE:1925862.673981617
# ARIMA(0, 0, 2)x(1, 1, 1, 12)12 
# ARIMA(1, 2, 0)x(0, 2, 0, 12)12 - MSE:421069.4801483329
# ARIMA(1, 2, 0)x(0, 2, 1, 12)12 - MSE:449105.62956239644
# ARIMA(1, 2, 0)x(0, 2, 2, 12)12 - MSE:453090.7400143462
# ARIMA(1, 2, 0)x(1, 0, 0, 12)12 - MSE:199275.4571203983
# ARIMA(1, 2, 0)x(1, 0, 1, 12)12 - MSE:194725.37126302478
# ARIMA(1, 2, 0)x(1, 0, 2, 12)12 - MSE:197631.51953970586
# ARIMA(1, 2, 0)x(1, 1, 0, 12)12 - MSE:256930.39103812457
# ARIMA(1, 2, 0)x(1, 1, 1, 12)12 - MSE:254715.7584782815
# ARIMA(1, 2, 0)x(1, 1, 2, 12)12 - MSE:251800.85216430263
# ARIMA(1, 2, 0)x(1, 2, 0, 12)12 - MSE:449105.62956239644
# ARIMA(1, 2, 0)x(1, 2, 1, 12)12 - MSE:449105.62956239644
# ARIMA(1, 2, 0)x(1, 2, 2, 12)12 - MSE:453090.7400143462
# ARIMA(1, 2, 0)x(2, 0, 0, 12)12 - MSE:252656.38776273368
# ARIMA(1, 2, 0)x(2, 0, 1, 12)12 - MSE:252236.87652496056
# ARIMA(1, 2, 0)x(2, 0, 2, 12)12 - MSE:252261.57841900777
# ARIMA(1, 2, 0)x(2, 1, 0, 12)12 - MSE:251800.85216430263
# ARIMA(1, 2, 0)x(2, 1, 1, 12)12 - MSE:251800.85216430263
# ARIMA(1, 2, 0)x(2, 1, 2, 12)12 - MSE:251800.85216430263
# ARIMA(1, 2, 0)x(2, 2, 0, 12)12 - MSE:453090.7400143462
# ARIMA(1, 2, 0)x(2, 2, 1, 12)12 - MSE:453090.7400143462
# ARIMA(1, 2, 0)x(2, 2, 2, 12)12 - MSE:453090.7400143462
# ARIMA(1, 2, 1)x(0, 0, 0, 12)12 - MSE:193608.8317913951
# ARIMA(1, 2, 1)x(0, 0, 1, 12)12 - MSE:193880.41807299436
# ARIMA(1, 2, 1)x(0, 0, 2, 12)12 - MSE:209162.77048369448
# ARIMA(1, 2, 1)x(0, 1, 0, 12)12 - MSE:230213.64211633615
# ARIMA(1, 2, 1)x(0, 1, 1, 12)12 - MSE:231381.6436752244
# ARIMA(1, 2, 1)x(0, 1, 2, 12)12 - MSE:273231.8591410608
# ARIMA(1, 2, 1)x(0, 2, 0, 12)12 - MSE:404396.53162382153
# ARIMA(1, 2, 1)x(0, 2, 1, 12)12 - MSE:443033.6227074748
# ARIMA(1, 2, 1)x(0, 2, 2, 12)12 - MSE:446961.6426662954
# ARIMA(1, 2, 1)x(1, 0, 0, 12)12 - MSE:193935.8501930247
# ARIMA(1, 2, 1)x(1, 0, 1, 12)12 - MSE:192710.39695129546
# ARIMA(1, 2, 1)x(1, 0, 2, 12)12 - MSE:191844.29509071796
# ARIMA(1, 2, 1)x(1, 1, 0, 12)12 - MSE:245532.1434930442
# ARIMA(1, 2, 1)x(1, 1, 1, 12)12 - MSE:249758.3746984259
# ARIMA(1, 2, 1)x(1, 1, 2, 12)12 - MSE:273231.8591410608
# ARIMA(1, 2, 1)x(1, 2, 0, 12)12 - MSE:437728.2848611741
# ARIMA(1, 2, 1)x(1, 2, 1, 12)12 - MSE:443033.6227074748
# ARIMA(1, 2, 1)x(1, 2, 2, 12)12 - MSE:446961.6426662954
# ARIMA(1, 2, 1)x(2, 0, 0, 12)12 - MSE:233242.02629494749
# ARIMA(1, 2, 1)x(2, 0, 1, 12)12 - MSE:234319.18499933995
# ARIMA(1, 2, 1)x(2, 0, 2, 12)12 - MSE:234835.66195857085
# ARIMA(1, 2, 1)x(2, 1, 0, 12)12 - MSE:272568.11004017264
# ARIMA(1, 2, 1)x(2, 1, 1, 12)12 - MSE:272568.11004017264
# ARIMA(1, 2, 1)x(2, 1, 2, 12)12 - MSE:273231.8591410608
# ARIMA(1, 2, 1)x(2, 2, 0, 12)12 - MSE:448019.0217666833
# ARIMA(1, 2, 1)x(2, 2, 1, 12)12 - MSE:448019.0217666833
# ARIMA(1, 2, 1)x(2, 2, 2, 12)12 - MSE:446961.6426662954
# ARIMA(1, 2, 2)x(0, 0, 0, 12)12 - MSE:174200.71875862367
# ARIMA(1, 2, 2)x(0, 0, 1, 12)12 - MSE:178963.05989782175
# ARIMA(1, 2, 2)x(0, 0, 2, 12)12 - MSE:202352.9170321289
# ARIMA(1, 2, 2)x(0, 1, 0, 12)12 - MSE:234415.38812395823
# ARIMA(1, 2, 2)x(0, 1, 1, 12)12 - MSE:231086.7035640121
# ARIMA(1, 2, 2)x(0, 1, 2, 12)12 - MSE:240467.64347105075
# ARIMA(1, 2, 2)x(0, 2, 0, 12)12 - MSE:409165.96553375485
# ARIMA(1, 2, 2)x(0, 2, 1, 12)12 - MSE:1665443.7179906585
# ARIMA(1, 2, 2)x(0, 2, 2, 12)12 - MSE:1692283.9375375179
# ARIMA(1, 2, 2)x(1, 0, 0, 12)12 - MSE:179415.9020867891
# ARIMA(1, 2, 2)x(1, 0, 1, 12)12 - MSE:192798.43956269877
# ARIMA(1, 2, 2)x(1, 0, 2, 12)12 - MSE:216135.5331030248
# ARIMA(1, 2, 2)x(1, 1, 0, 12)12 - MSE:282366.4101054435
# ARIMA(1, 2, 2)x(1, 1, 1, 12)12 - MSE:231256.1289531516
# ARIMA(1, 2, 2)x(1, 1, 2, 12)12 - MSE:240467.64347105075
# ARIMA(1, 2, 2)x(1, 2, 0, 12)12 - MSE:1649116.4665985669
# ARIMA(1, 2, 2)x(1, 2, 1, 12)12 - MSE:1665443.7179906585
# ARIMA(1, 2, 2)x(1, 2, 2, 12)12 - MSE:1692283.9375375179
# ARIMA(1, 2, 2)x(2, 0, 0, 12)12 - MSE:256686.5812246395
# ARIMA(1, 2, 2)x(2, 0, 1, 12)12 - MSE:228161.70765137725
# ARIMA(1, 2, 2)x(2, 0, 2, 12)12 - MSE:198351.58482172445
# ARIMA(1, 2, 2)x(2, 1, 0, 12)12 - MSE:237087.68573804267
# ARIMA(1, 2, 2)x(2, 1, 1, 12)12 - MSE:237087.68573804267
# ARIMA(1, 2, 2)x(2, 1, 2, 12)12 - MSE:240467.64347105075
# ARIMA(1, 2, 2)x(2, 2, 0, 12)12 - MSE:1687470.5406600505
# ARIMA(1, 2, 2)x(2, 2, 1, 12)12 - MSE:1687470.5406600505
# ARIMA(1, 2, 2)x(2, 2, 2, 12)12 - MSE:1692283.9375375179
# ARIMA(2, 0, 0)x(0, 0, 0, 12)12 - MSE:148950.07912260492
# ARIMA(2, 0, 0)x(0, 0, 1, 12)12 - MSE:141295.88378198634
# ARIMA(2, 0, 0)x(0, 0, 2, 12)12 - MSE:149321.214242845
# ARIMA(2, 0, 0)x(0, 1, 0, 12)12 - MSE:1518752.606459204
# ARIMA(2, 0, 0)x(0, 1, 1, 12)12 - MSE:859571.5568493588
# ARIMA(2, 0, 0)x(0, 1, 2, 12)12 - MSE:1484882.204415835
# ARIMA(2, 0, 0)x(0, 2, 0, 12)12 - MSE:1976765.2288199018
# ARIMA(2, 0, 0)x(0, 2, 1, 12)12 - MSE:2390530.6788285472
# ARIMA(2, 0, 0)x(0, 2, 2, 12)12 - MSE:2512774.9801275646
# ARIMA(2, 0, 0)x(1, 0, 0, 12)12 - MSE:1976776.7791865186
# ARIMA(2, 0, 0)x(1, 0, 1, 12)12 - MSE:1463255.4798625102
# ARIMA(2, 0, 0)x(1, 0, 2, 12)12 - MSE:208325.86727935108
# ARIMA(2, 0, 0)x(1, 1, 0, 12)12 - MSE:1052251.1914662672
# ARIMA(2, 0, 0)x(1, 1, 1, 12)12 - MSE:1213982.8998062217
# ARIMA(2, 0, 0)x(1, 1, 2, 12)12 - MSE:1484882.204415835
# ARIMA(2, 0, 0)x(1, 2, 0, 12)12 - MSE:2396037.8738291254
# ARIMA(2, 0, 0)x(1, 2, 1, 12)12 - MSE:2396037.8738291254
# ARIMA(2, 0, 0)x(1, 2, 2, 12)12 - MSE:2512774.9801275646
# ARIMA(2, 0, 0)x(2, 0, 0, 12)12 - MSE:1872905.621488235
# ARIMA(2, 0, 0)x(2, 0, 1, 12)12 - MSE:1873448.9023149721

# %%
# Building the model and forecasting
model = SARIMAX(df_data_x['PJM_Load_MW'], order = (1,1,1), seasonal_order = (0,1,0,12))
model_fit = model.fit()
model_fit.forecast(len(df_data_y))

# %%
# Get MAPE score for the model
mape(model_fit.forecast(len(df_data_y)), df_data_y)

# %%
plt.plot(model_fit.forecast(len(df_data_y)), label='Forecast')
plt.plot(df_data_y, label='Actual')
plt.legend(prop={'size': 10})
#matplotlib.rc('xtick', labelsize=35) 
#matplotlib.rc('ytick', labelsize=35)
plt.show()
